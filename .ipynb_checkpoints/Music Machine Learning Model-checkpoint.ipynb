# %% [markdown]
# # Overview:
# Given User's age and gender build Machine Learning Model that predicts which album user most likely to buy.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('music.csv')
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
df.shape
# Out:
# (18, 3)

# %%
X = df.drop(columns=["genre"])
y = df["genre"]

# %%
X.head(1)
# Out:
#    age  gender
# 0   20       1

# %%
y.head(1)
# Out:
# 0    HipHop
# Name: genre, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict = model.predict(X_test)

# %%
score = accuracy_score(y_test,predict)
score
# Out:
# 1.0

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(model,feature_names = ["age","gender"],
               class_names=sorted(y.unique()),
               label = 'all',
               rounded=True,
               filled=True)
# Out:
# [Text(0.625, 0.875, 'age <= 30.5\ngini = 0.755\nsamples = 14\nvalue = [3, 5, 3, 2, 1]\nclass = Classical'),
#  Text(0.5, 0.625, 'age <= 25.5\ngini = 0.716\nsamples = 9\nvalue = [3, 0, 3, 2, 1]\nclass = Acoustic'),
#  Text(0.25, 0.375, 'gender <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0]\nclass = Dance'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = Dance'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = HipHop'),
#  Text(0.75, 0.375, 'gender <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 0, 1]\nclass = Acoustic'),
#  Text(0.625, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Acoustic'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Jazz'),
#  Text(0.75, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0]\nclass = Classical')]
